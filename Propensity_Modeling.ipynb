# %% [markdown]
# <a href="https://colab.research.google.com/github/pjcroxas/Data-Analytics-Case-Studies/blob/main/Propensity_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Propensity Modeling of Customer Purchasing**

# %%
+import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dir = "/content/drive/My Drive/Data Science Portfolio/2023/Applied/data/propensity"
ui_df_train = pd.read_csv(dir+"/training_sample.csv", sep=",")
ui_df_test = pd.read_csv(dir+"/testing_sample.csv", sep=",")
ui_df_train.sample(3)
# Out:
#                                      UserID  basket_icon_click  \
# 70302     b1b6-d2618460-b1b6-41e4-80a7-2724                  1
# 66488   2016-d740317c-2016-4b27-8a37-747399                  0
# 224285  1cc3-80d1e6b2-1cc3-421c-9072-333608                  0
#
#         basket_add_list  basket_add_detail  sort_by  image_picker  \
# 70302                 1                  1        0             0
# 66488                 0                  0        0             0
# 224285                0                  0        0             0
#
#         account_page_click  promo_banner_click  detail_wishlist_add  \
# 70302                    0                   0                    0
# 66488                    0                   0                    0
# 224285                   0                   0                    0
#
#         list_size_dropdown  ...  saw_sizecharts  saw_delivery  \
# 70302                    1  ...               0             0
# ...
